# %%
import pyspark
if not 'sc' in globals():
    sc = pyspark.SparkContext()

text_file = sc.textFile("Spark File Words.ipynb")
counts = text_file.flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)
for x in counts.collect():
    print x
# Out:
# (u'', 1323)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"cell_type\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"cell_type\\":\',', 1)
# (u'"if', 1)
# (u'"(u\'\\"cells\\":\',', 1)
# (u'"(u\'word:\',', 1)
# (u'"(u\'\\"(u\\\\\'},\\\\\',\',', 1)
# (u'"version":', 2)
# (u'"(u\'\\"text_file\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"python2\\\\\\\\\\"\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"pygments_lexer\\\\\\\\\\":\\\\\',\',', 1)
# (u'\\\\\\n",', 2)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"ipython\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'},\',', 1)
# (u'"(u\'2\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"mimetype\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"collapsed\\":\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"language\\\\\\\\\\":\\\\\',\',', 1)
# (u'"nbformat_minor":', 1)
# (u'"(u\'\\"(u\\\\\'^\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001bSyntaxError\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b:\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\',\',', 1)
# (u'"(u\'pyspark.SparkContext()\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"language_info\\":\',', 1)
# (u'"(u\'\\"language\\":\',', 1)
# (u'779)\\n",', 1)
# (u'"(u\'line:\',', 1)
# (u'not', 1)
# (u'"(u\'\\"(u\\\\\'pyspark\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'syntax\\\\\',\',', 1)
# (u'"(u\'8)\\\\\\\\n\\",\',', 1)
# (u"'sc'", 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"cells\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'],\\\\\',\',', 1)
# (u'text_file.flatMap(lambda', 1)
# (u'"(u\'\\"display_name\\":\',', 1)
# (u'counts.collect():\\n",', 1)
# (u'"outputs":', 1)
# (u'"(u\'x\',', 1)
# (u'"(u\'2)\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"text/x-python\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"display_name\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"text/x-python\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'=>\\\\\',\',', 1)
# (u'"(u\'line.split(\\\\\\\\\\"\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"SyntaxError\\\\\\\\\\",\\\\\',\',', 1)
# (u'"codemirror_mode":', 1)
# (u'"(u\'0\',', 1)
# (u'"import', 1)
# (u'Words.ipynb\\")\\n",', 1)
# (u'+', 1)
# (u'"(u\'\\"2.7.11\\"\',', 1)
# (u'"(u\'\\"(u\\\\\'a,\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"python\\\\\\\\\\",\\\\\',\',', 1)
# (u'.map(lambda', 1)
# (u'print', 1)
# (u'"(u\'\\"if\',', 1)
# (u'1))', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"file_extension\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'x\\"\',', 1)
# (u'\\"))', 1)
# (u'"(u\'\\"(u\\\\\'pyspark.SparkContext()\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"kernelspec\\\\\\\\\\":\\\\\',\',', 1)
# (u'"text_file', 1)
# (u'"nbconvert_exporter":', 1)
# (u'[', 4)
# (u'"code",', 1)
# (u'"(u\'\\"(u\\\\\'in\\\\\',\',', 1)
# (u'"(u\'in\',', 1)
# (u'"(u\'\\"(u\\\\\'(<ipython-input-5-78889f28c230>,\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"evalue\\\\\\\\\\":\\\\\',\',', 1)
# (u'1)\\n",', 169)
# (u'{', 8)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"text_file\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'print(line))\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\',\',', 1)
# (u'"(u\'a,\',', 1)
# (u'"stdout",', 1)
# (u'(word,', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"import\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"language_info\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'line:\\\\\',\',', 1)
# (u'"(u\'1)\\\\\\\\n\\"\',', 1)
# (u'"execution_count":', 1)
# (u'"(u\'pyspark\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'globals():\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"mimetype\\":\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\".py\\\\\\\\\\",\\\\\',\',', 1)
# (u'"source":', 1)
# (u'"(u\'\\"(u\\\\\'sc.textFile(\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"Spark\\\\\',\',', 1)
# (u'"(u\'\\".py\\",\',', 1)
# (u'"(u\'\\"kernelspec\\":\',', 1)
# (u'"(u\'\\"(u\\\\\'b)\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"python\\",\',', 1)
# (u'"(u\'\\"file_extension\\":\',', 1)
# (u'"ipython2",', 1)
# (u'"metadata":', 2)
# (u'"(u\'\\"stream\\",\',', 1)
# (u'"(u\'4)\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'7)\\\\\\\\\\",\\\\\',\',', 1)
# (u'"text":', 1)
# (u'"output_type":', 1)
# (u'"(u\'\\"(u\\\\\'5,\\\\\',\',', 1)
# (u'.reduceByKey(lambda', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"2.7.11\\\\\\\\\\"\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'x\\\\\\\\\\"\\\\\',\',', 1)
# (u'false', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"if\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'x\\\\\',\',', 1)
# (u'"nbformat":', 1)
# (u'"(u\'\\"(u\\\\\'line.split(\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'word:\\\\\',\',', 1)
# (u'"name":', 4)
# (u'"plot(counts)"', 1)
# (u'4,', 1)
# (u'"(u\'\\"(u\\\\\'2\\\\\',\',', 1)
# (u'b:', 1)
# (u'"(u\'\\"python2\\"\',', 1)
# (u'=', 3)
# (u'"(u\'\\"import\',', 1)
# (u'"(u\'sc.textFile(\\\\\\\\\\"Spark\',', 1)
# (u'"(u\'b)\\\\\\\\n\\",\',', 1)
# (u'"(u\'],\',', 1)
# (u'"(u\'globals():\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"ipython\\",\',', 1)
# (u'"(u\'\\"pygments_lexer\\":\',', 1)
# (u']', 2)
# (u'3)\\n",', 3)
# (u'a', 1)
# (u'"(u\'\\"(u\\\\\'0\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"collapsed\\\\\\\\\\":\\\\\',\',', 1)
# (u'File', 1)
# (u'sc', 1)
# (u'}', 4)
# (u'"(u\'\\"(u\\\\\'syntax\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\"\\\\\',\',', 1)
# (u'"(u\'counts.collect():\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"error\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'File\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'{\\\\\',\',', 1)
# (u'4)\\n",', 6)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"))\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'1))\\\\\',\',', 1)
# (u'"counts', 1)
# (u'"(u\'\\"execution_count\\":\',', 1)
# (u'0', 1)
# (u'"(u\'\\"for\',', 1)
# (u'"display_name":', 1)
# (u'"language":', 1)
# (u'"(u\'false\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"execution_count\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"nbconvert_exporter\\":\',', 1)
# (u'"(u\'\\"counts\',', 1)
# (u'".py",', 1)
# (u'"(u\'File\',', 1)
# (u'"(u\'sc\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"ename\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\']\\\\\',\',', 1)
# (u'"(u\'\\"text\\":\',', 1)
# (u'"language_info":', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"Python\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"output_type\\\\\\\\\\":\\\\\',\',', 1)
# (u'"cells":', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"codemirror_mode\\\\\\\\\\":\\\\\',\',', 1)
# (u'x', 1)
# (u'"(u\'\\"source\\":\',', 1)
# (u'"(u\'\\"\',', 1)
# (u'"ipython",', 1)
# (u'pyspark\\n",', 1)
# (u'"(u\'2\\",\',', 1)
# (u'"\\n",', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"counts\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"outputs\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'counts.collect():\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'2\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"nbformat\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"version\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'.reduceByKey(lambda\',', 1)
# (u'"(u\'\\"(u\\\\\'not\\\\\',\',', 1)
# (u'"stream",', 1)
# (u'"(u\'.map(lambda\',', 1)
# (u'"(u\'\\"(u\\\\\'+\\\\\',\',', 1)
# (u'"mimetype":', 1)
# (u'"(u\'\\"(u\\\\\'(word,\\\\\',\',', 1)
# (u'"(u\\"\'sc\'\\",', 1)
# (u'"file_extension":', 1)
# (u'"(u\'1))\',', 1)
# (u'pyspark.SparkContext()\\n",', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"ipython2\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'3)\\\\\\\\n\\",\',', 1)
# (u'"kernelspec":', 1)
# (u'1)\\n"', 1)
# (u'"(u\'Words.ipynb\\\\\\\\\\")\\\\\\\\n\\",\',', 1)
# (u'"(u\'=\',', 1)
# (u'1,', 1)
# (u'"(u\'\',', 1)
# (u'"(u\'\\"version\\":\',', 1)
# (u'"Python', 1)
# (u'"(u\'\\"(u\\\\\'line\\\\\',\',', 1)
# (u'],', 2)
# (u'"(u\'(word,\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b7\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"code\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'[\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'}\\\\\',\',', 1)
# (u'sc.textFile(\\"Spark', 1)
# (u'line.split(\\"', 1)
# (u'},', 4)
# (u'"(u\'\\"(u\\\\\'.map(lambda\\\\\',\',', 1)
# (u'"(u\'\\"ipython2\\",\',', 1)
# (u'"python",', 3)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"nbconvert_exporter\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'234)\\\\\\\\n\\",\',', 1)
# (u'"text/x-python",', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"for\\\\\',\',', 1)
# (u'"(u\'\\"metadata\\":\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"invalid\\\\\',\',', 1)
# (u'2', 1)
# (u'"(u\'\\"(u\\\\\'a\\\\\',\',', 1)
# (u'"(u\'\\"outputs\\":\',', 1)
# (u'"pygments_lexer":', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"source\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'6,\',', 1)
# (u'"(u\'\\"codemirror_mode\\":\',', 1)
# (u'"(u\'\\"(u\\\\\\\\\\"\\\\\'sc\\\\\'\\\\\\\\\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"traceback\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'print\',', 1)
# (u'"(u\'\\"output_type\\":\',', 1)
# (u'"(u\'b:\',', 1)
# (u'globals():\\n",', 1)
# (u'"(u\'\\"(u\\\\\'text_file.flatMap(lambda\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'false\\\\\',\',', 1)
# (u'"(u\'\\"nbformat_minor\\":\',', 1)
# (u'"(u\'\\"(u\\\\\'4,\\\\\',\',', 1)
# (u'"2.7.11"', 1)
# (u'"(u\'\\"(u\\\\\'counts.toArray().foreach(line\\\\\',\',', 1)
# (u'x\\n",', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"metadata\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\\\\\\\\\\\\\\\\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"\\\\\\\\n\\",\',', 1)
# (u'"(u\'[\',', 1)
# (u'"(u\'not\',', 1)
# (u'word:', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"<ipython-input-5-78889f28c230>\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b,\\\\\',\',', 1)
# (u'81)\\n",', 1)
# (u'"cell_type":', 1)
# (u'"(u\']\',', 1)
# (u'"(u\'+\',', 1)
# (u'"(u\'\\"(u\\\\\'.reduceByKey(lambda\\\\\',\',', 1)
# (u'in', 2)
# (u'"collapsed":', 1)
# (u'"(u\'text_file.flatMap(lambda\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'b:\\\\\',\',', 1)
# (u'line:', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'Words.ipynb\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\")\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\",\\\\\',\',', 1)
# (u'b)\\n",', 1)
# (u'"(u\'\\"code\\",\',', 1)
# (u'2",', 1)
# (u'"(u\'a\',', 1)
# (u'"', 4)
# (u'"(u\'\\"(u\\\\\'invalid\\\\\',\',', 1)
# (u'"(u\'1)\\\\\\\\n\\",\',', 1)
# (u'"(u\'\\"(u\\\\\'sc\\\\\',\',', 1)
# (u'a,', 1)
# (u'"(u\'\\"(u\\\\\'=\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"nbformat_minor\\\\\\\\\\":\\\\\',\',', 1)
# (u'"for', 1)
# (u'8)\\n",', 2)
# (u'"(u\'{\',', 1)
# (u'"python2"', 1)
# (u'2)\\n",', 6)
# (u'"(u\'4,\',', 1)
# (u'"(u\'\\\\\\\\\\"))\',', 1)
# (u'"(u\'\\"Python\',', 1)
# (u'"(u\'\\"nbformat\\":\',', 1)
# (u'"(u\'}\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"name\\\\\\\\\\":\\\\\',\',', 1)
# (u'"(u\'\\"(u\\\\\'\\\\\\\\\\"\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u001b\\\\\',\',', 1)
# (u'"(u\'\\"name\\":\',', 1)
# (u'"(u\'\\"(u\\\\\'print\\\\\',\',', 1)
# (u'"(u\'\\"stdout\\",\',', 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f25981b7a3ef> in <module>()
#       7 for x in counts.collect():
#       8     print x
# ----> 9 plot(counts)
#
# NameError: name 'plot' is not defined
